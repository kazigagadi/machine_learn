# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# 中文乱码的处理
plt.rcParams['font.sans-serif'] =['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size'] =16

# %%
# 读取数据
chengjiao=pd.read_excel(r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\区域进客来源.xlsx",sheet_name="成交")
jinke=pd.read_excel(r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\区域进客来源.xlsx",sheet_name="进客")

# %%
chengjiao.groupby("城市")["城市"].count().plot(kind="pie")
plt.axis("equal")
# Out:
# (-1.1139650026892276,
#  1.1006650001280585,
#  -1.1077289444012774,
#  1.111344711344479)

# %%
index=(chengjiao["城市"]=="上海市") & (chengjiao["合同类型"]=="新签") & (chengjiao["出租合同状态"]=="有效")
shcj=chengjiao.loc[index,:]
# shcj.groupby("城区")["城市"].count().plot(kind="bar",figsize=(10,8))
shcj.groupby("城区")["业绩"].mean().plot(kind="bar",figsize=(10,8))
plt.title("上海新签订单区域比较")
# Out:
# Text(0.5, 1.0, '上海新签订单区域比较')
