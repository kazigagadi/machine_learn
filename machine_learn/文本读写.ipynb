# %%
import pandas as pd

# %%
# 读取文本
path=r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\51job技能.txt"
f=open(path,encoding="utf-8")
df=pd.read_table(path)
df.info
# Out:
# <bound method DataFrame.info of      负责海外渠道投放的分析和专项研究工作，对海外游戏、市场、竞争对手保持持续关注，通过多维度，全视角分析，为渠道投放策略制定提供决策支持；负责项目的需求调研、数据分析、商业分析和数据挖掘模型等，通过对市场数据分析洞察市场动态，提供市场推广优化建议；产出商业数据分析报告，解读第三方市场报告，及时发现和分析其中隐含的变化和问题，为业务发展提供决策支持；持续跟踪及引入前沿市场推广技术3年以上游戏数据分析和战略规划工作经验，曾就职于大型互联网公司战略规划、行业分析部门、业内知名管理咨询公司、大型投行/VC/PE等投资机构的TMT行业分析师优先考虑；目标导向，能主动的推动项目，具备良好的沟通能力及汇报能力持续关注行业动向，快速且喜爱学习新知识，能够创造性地和战略性地思考能熟练运用MS Office、全球性的数据监控工具及数据分析工具数据分析、通讯或相关领域的学士/学士优先中英文沟通能力优秀，并能用作工作语言 职能类别： 市场分析/调研人员 微信分享
# 0      岗位职责：1.能够利用不同方式方法，基于已有用户数据进行分析，需求挖掘并形成有效转化，解决...
# 1      岗位职责：1、对生产和实验中的各种数据进行归纳整理和深入分析研究；2、参与或负责企业内技术...
# 2      岗位职责：负责专营店的所有展车钥匙的保管负责日常业绩统计处理及报表制作协助销售顾问工作负责...
# 3      岗位职责：1、 负责业务线条（旅游、酒店）的数据管理与分析、需求调研，与业务部门对接，分析...
# 4      岗位职责：1、主要协助分析师工作，包括数据整理、分析，行情分析、传达，技术分析、授课。2、...
# ...                                                 ...
# 4892   1、对各类场景下的信贷产品进行客户分群、资产盈亏预算、价格敏感度测试及风险定价；2、评估第...
# 4893   （一） 岗位职责：1、负责每日数据研判分析及管控建议推送工作；2、结合国控站当日监测数据、...
# 4894   岗位职责： 1、负责数据库安装、部署及日常运维工作； 2、负责完成数据采集、诊断、清洗、汇...
# ...

# %%
path=r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\titanic_train.csv"
f=open(path,encoding="utf-8")
df=pd.read_csv(f) #header=None 不设置表头 hearder=1 设置第几行数据为表头
f.close()
# print(df.head(10))
# print(type(df))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# 读取Excel数据
path=r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\区域进客来源.xlsx"
df=pd.read_excel(path)
df.head(10)
# Out:
#     城市   城区        业务区    门店      业务组 出租合同签约人部门 出租合同签约人   出租合同提交时间  \
# 0  杭州市  滨江区  滨江一区（吴嘉伟）   西兴店   西兴综合一组    西兴综合一组     侯乐义 2017-12-24
# 1  杭州市  滨江区  滨江一区（吴嘉伟）   西兴店   西兴综合二组    西兴综合二组      孙钧 2017-12-21
# 2  杭州市  萧山区  滨江一区（吴嘉伟）   奥体店   奥体综合二组    奥体综合二组      李玉 2017-12-23
# 3  杭州市  滨江区  滨江一区（吴嘉伟）  区政府店  区政府综合五组   区政府综合五组      刘振 2017-12-20
# 4  杭州市  滨江区  滨江一区（吴嘉伟）  区政府店  区政府综合三组   区政府综合三组     黄克重 2017-12-19
# 5  杭州市  滨江区  滨江一区（吴嘉伟）  区政府店  区政府综合一组   区政府综合一组      张义 2017-12-19
# 6  杭州市  滨江区  滨江一区（吴嘉伟）  区政府店  区政府综合一组   区政府综合一组     蔡家旺 2017-12-19
# 7  杭州市  滨江区  滨江一区（吴嘉伟）  区政府店  区政府综合一组   区政府综合一组      许洁 2017-12-21
# 8  杭州市  滨江区  滨江一区（吴嘉伟）  区政府店  区政府综合一组   区政府综合一组     汪小博 2017-12-23
# 9  杭州市  江干区    中区（周保红）   和平店   和平综合三组    和平综合三组      刘博 2017-12-20
#
#              房源编号         统计型房源编号  ...       置信度  下一份委托合同起算日 下一份委托合同实际到期日  \
# 0      BJM2002833      BJM2002833  ...  0.922943         NaN          NaN
# 1      BJM1005868      BJM1005868  ...       NaN         NaN          NaN
# ...

# %%
# 读取Excel数据指定工作簿
path=r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\区域进客来源.xlsx"
# df=pd.read_excel(path,sheet_name=0)
# print(df.head())
# df2=pd.read_excel(path,sheet_name=1)
# print(df2.head())
# df=pd.read_excel(path,sheet_name='成交')
# print(df.head())
# df2=pd.read_excel(path,sheet_name="进客")
# print(df2.head())
df=pd.read_excel(path,sheet_name=[0,1])
df=df[0]
# df.to_csv(r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\kk.csv"
#              ,index=False)
write=pd.ExcelWriter()
df.to_excel(r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\kk.xlsx")
# print(df)

# %%
# 多个DataFrame保存保存Excel工作簿
write=pd.ExcelWriter(r"F:\DataAnalysis\python\资料\全日制3班_20200507总结\数据分析课件\haha.xlsx")
df.to_excel(write,'第一个')
df.to_excel(write,'第二个')
write.save()
